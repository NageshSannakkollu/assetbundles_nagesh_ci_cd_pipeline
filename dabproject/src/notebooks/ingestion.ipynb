# %% [markdown]
# **Instead of Hard coding the catalog_name,we use parameterised the catalog name.In real scenario work on different environments like dev,prod and QA.Each env have seperate catalog for it.**

# %%
dbutils.widgets.text("catalog_name","")

# %%
catalog_name = dbutils.widgets.get("catalog_name")

# %%
df = spark.sql(f"SELECT * FROM {catalog_name}.information_schema.columns")
display(df)
